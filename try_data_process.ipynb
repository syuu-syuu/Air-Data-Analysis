# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('./SelectedIndicators/ClimateChange/CDA_ind.csv')
df
# Out:
#      code  iso                    country  CDA.ind.1995  CDA.ind.1996  \
# 0       4  AFG                Afghanistan      0.000000      0.000000
# 1       8  ALB                    Albania    100.000000    100.000000
# 2      12  DZA                    Algeria     34.015600     34.015600
# 3      20  AND                    Andorra  -8888.000000  -8888.000000
# 4      24  AGO                     Angola      2.134042      2.134042
# ..    ...  ...                        ...           ...           ...
# 215   876  WLF  Wallis and Futuna Islands  -8888.000000  -8888.000000
# 216   732  ESH             Western Sahara  -8888.000000  -8888.000000
# 217   887  YEM                      Yemen     15.544092     15.544092
# 218   894  ZMB                     Zambia     70.086144     70.086144
# 219   716  ZWE                   Zimbabwe     60.650485     60.650485
#
#      CDA.ind.1997  CDA.ind.1998  CDA.ind.1999  CDA.ind.2000  CDA.ind.2001  \
# ...

# %%
df.set_index(['code', 'iso', 'country'], inplace=True)
df.index.names = [None, None, None]

# %%
df_trans = df.T
df_trans
# Out:
#                      4           8          12      20         24       660  \
#                      AFG         ALB        DZA     AND        AGO      AIA
#              Afghanistan     Albania    Algeria Andorra     Angola Anguilla
# CDA.ind.1995    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# CDA.ind.1996    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# CDA.ind.1997    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# CDA.ind.1998    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# CDA.ind.1999    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# CDA.ind.2000    0.000000   70.711776  39.507944 -8888.0   7.996337  -8888.0
# CDA.ind.2001    0.000000   31.235373  46.288313 -8888.0  16.020780  -8888.0
# CDA.ind.2002    0.000000    9.009048  50.189674 -8888.0  25.391659  -8888.0
# CDA.ind.2003    0.000000    0.000000  52.633144 -8888.0  32.521894  -8888.0
# ...

# %%
df_trans = df_trans.reset_index()

# %%
df_trans['index'] = df_trans['index'].str[-4:]
df_new = df_trans.set_index('index')
df_new.index.names = [None]

# %%
df_new
# Out:
#              4           8          12      20         24       660  \
#              AFG         ALB        DZA     AND        AGO      AIA
#      Afghanistan     Albania    Algeria Andorra     Angola Anguilla
# 1995    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# 1996    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# 1997    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# 1998    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# 1999    0.000000  100.000000  34.015600 -8888.0   2.134042  -8888.0
# 2000    0.000000   70.711776  39.507944 -8888.0   7.996337  -8888.0
# 2001    0.000000   31.235373  46.288313 -8888.0  16.020780  -8888.0
# 2002    0.000000    9.009048  50.189674 -8888.0  25.391659  -8888.0
# 2003    0.000000    0.000000  52.633144 -8888.0  32.521894  -8888.0
# 2004    0.000000    0.000000  56.195851 -8888.0  59.583613  -8888.0
# 2005    0.000000    0.000000  46.950008 -8888.0  61.006342  -8888.0
# ...
